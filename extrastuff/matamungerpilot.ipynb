# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.cluster import KMeans
import glob
import os
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn import preprocessing
import csv
import re
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import statsmodels.api as sm

# %%
for filename in glob.iglob("C:\Users\DaBoss\Desktop\data/*.csv*"):
    temp = open(filename, 'r')
    temp2 = temp.read().splitlines()
    print len(temp2)
    rowlen = "--"
    for i in range (0,len(temp2)):
        vabs = temp2[i].split('!')
        #templist.append(vabs)
        rowlen = rowlen + str(len(vabs))
    print rowlen
# Out:
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181818121
# --11818181818181818111
# --11818181818181818111
# --11818181818181818111
# --11818181818181
# --11818181818181818111
# --11818118818118181811
# --11818181818181818111
# --11818181818181
# --11818181818181818111

# %%
for filename in glob.iglob("C:\Users\DaBoss\Desktop\data/*.csv*"):
    temp = open(filename, 'r')
    temp2 = temp.read().splitlines()
    print len(temp2)
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 14
# 20
# 20
# 20
# 14
# 20

# %%
lesstemplist = []
df = pd.DataFrame(columns=['accratio', 'Xcord', 'Ycord','Timemousecords','timestimsarrive','difficultylevel','stimsclicked','stimsshown'])

for filename in glob.iglob("C:\Users\DaBoss\Desktop\data/*.csv*"):
    temp = open(filename, 'r')
    temp2 = temp.read().splitlines()
    
    templist = []
    for i in range (len(temp2)):
        if len(temp2[i])>1000:
            vabs = temp2[i].split('!')
        #templist.append(vabs)
            lesstemplist.append(vabs)
    #newdf = pd.DataFrame(templist,columns=['accratio', 'Xcord', 'Ycord','Timemousecords','timestimsarrive','difficultylevel','stimsclicked','stimsshown'])
#df = df.append(newdf, ignore_index = True)    
#df
testdf = pd.DataFrame(lesstemplist,columns=['accratio', 'Xcord', 'Ycord','Timemousecords','timestimsarrive','difficultylevel','stimsclicked','stimsshown'])
testdf

df = testdf

ids = []
for filename in glob.iglob("C:\Users\DaBoss\Desktop\data/*.csv*"):
    temp = open(filename, 'r')
    temp2 = temp.read().splitlines()
    numlines += len(temp2)
    if len(temp2[-1]) > len(temp2[-2]):
        x = temp2[-1]
        temp2[-1] = temp2[-2]
        temp2[-2] = temp2[-1]
        for i in range(len(temp2)):
            if len(temp2[i])>1000:
                if len(temp2[-1]) > 25:
                    ids.append("anon")
                else:
                    ids.append(temp2[-1])
                    counter += 1
    else:
        for i in range(len(temp2)):
            if len(temp2[i])>1000:
                if len(temp2[-1]) > 25:
                    ids.append("anon")
                else:
                    ids.append(temp2[-1])
                    counter += 1
se = pd.Series(ids)
df['IDs'] = se.values
df
# Out:
#                   accratio                                              Xcord  \
# 0      "0.3389830508474576  362,362,361,361,358,358,358,358,362,366,372,37...
# 1      "0.2597402597402597  362,362,361,361,358,358,358,358,362,366,372,37...
# 2      "0.2777777777777778  362,362,361,361,358,358,358,358,362,366,372,37...
# 3     "0.32786885245901637  362,362,361,361,358,358,358,358,362,366,372,37...
# 4     "0.18823529411764706  362,362,361,361,358,358,358,358,362,366,372,37...
# 5     "0.18181818181818182  362,362,361,361,358,358,358,358,362,366,372,37...
# 6      "0.2898550724637681  362,362,361,361,358,358,358,358,362,366,372,37...
# 7      "0.2597402597402597  362,362,361,361,358,358,358,358,362,366,372,37...
# 8     "0.24096385542168675  365,365,365,368,370,373,380,389,399,416,428,44...
# 9     "0.20454545454545456  365,365,365,368,370,373,380,389,399,416,428,44...
# 10     "0.1111111111111111  365,365,365,368,370,373,380,389,399,416,428,44...
# ...

# %%
ids = []
for filename in glob.iglob("C:\Users\DaBoss\Desktop\data/*.csv*"):
    temp = open(filename, 'r')
    temp2 = temp.read().splitlines()
    numlines += len(temp2)
    if len(temp2[-1]) > len(temp2[-2]):
        x = temp2[-1]
        temp2[-1] = temp2[-2]
        temp2[-2] = temp2[-1]
        for i in range(len(temp2)):
            if len(temp2[i])>1000:
                if len(temp2[-1]) > 25:
                    ids.append("anon")
                else:
                    ids.append(temp2[-1])
                    counter += 1
    else:
        for i in range(len(temp2)):
            if len(temp2[i])>1000:
                if len(temp2[-1]) > 25:
                    ids.append("anon")
                else:
                    ids.append(temp2[-1])
                    counter += 1
se = pd.Series(ids)
df['IDs'] = se.values
df
# Out:
#                   accratio                                              Xcord  \
# 0      "0.3389830508474576  362,362,361,361,358,358,358,358,362,366,372,37...
# 1      "0.2597402597402597  362,362,361,361,358,358,358,358,362,366,372,37...
# 2      "0.2777777777777778  362,362,361,361,358,358,358,358,362,366,372,37...
# 3     "0.32786885245901637  362,362,361,361,358,358,358,358,362,366,372,37...
# 4     "0.18823529411764706  362,362,361,361,358,358,358,358,362,366,372,37...
# 5     "0.18181818181818182  362,362,361,361,358,358,358,358,362,366,372,37...
# 6      "0.2898550724637681  362,362,361,361,358,358,358,358,362,366,372,37...
# 7      "0.2597402597402597  362,362,361,361,358,358,358,358,362,366,372,37...
# 8     "0.24096385542168675  365,365,365,368,370,373,380,389,399,416,428,44...
# 9     "0.20454545454545456  365,365,365,368,370,373,380,389,399,416,428,44...
# 10     "0.1111111111111111  365,365,365,368,370,373,380,389,399,416,428,44...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b9ff4d264371> in <module>()
#       1 for index, row in df.iterrows():
#       2     if len(df.iloc[index,8]) > 25:
# ----> 3         print df.loc[index,8].value
#
# C:\Users\DaBoss\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# C:\Users\DaBoss\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_tuple(self, tup)
#     782     def _getitem_tuple(self, tup):
#     783         try:
# --> 784             return self._getitem_lowerdim(tup)
#     785         except IndexingError:
#     786             pass
#
# ...
